# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
countries = ('Argentina', 'Bolivia', 'Brazil','Chile', 'Colombia', 'Ecuador', 'Falkland Islands', 'French Guiana', 'Guyana', 'Paraguay', 'Peru','Suriname', 'Uruguay', 'Venezuela')

# %%
populations = (45076704, 11626410, 212162757, 19109629, 50819826, 17579085, 3481, 287750, 785409, 7107305, 32880332, 585169, 3470475, 28258770)

# %%
df = pd.DataFrame({
    'Country': countries,
    'Population': populations
})

# %%
df.sort_values(by='Population', inplace=True)

# %%
x_coords = range(len(df))

# %%
colors = ['#0000FF' for _ in range(len(df))]

# %%
colors[-2] = '#FF0000'

# %%
plt.figure(figsize=(10, 6))  # mengubah ukuran fgur menjadi kecil

# %%
plt.bar(x_coords, df['Population'], tick_label=df['Country'], color=colors)
# Out:
# <BarContainer object of 14 artists>

# %%
plt.xticks(rotation=45)  # Mengatur rotasi label x menjadi 45 derajat
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.ylabel('Population (Millions)')
# Out:
# Text(0, 0.5, 'Population (Millions)')

# %%
plt.title('South American Populations')
# Out:
# Text(0.5, 1.0, 'South American Populations')

# %%
plt.tight_layout()  # Menyesuaikan layout agar tidak ada overlap

# %%
plt.show()

# %%
plt.bar(x_coords, df['Population'], tick_label=df['Country'], color=colors)
# Out:
# <BarContainer object of 14 artists>
