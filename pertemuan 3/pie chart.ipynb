# %%
import matplotlib.pyplot as plt

# %%
flavors = ('Chocolate', 'Vanilla',
# Out:
#   Cell In[2], line 1
#     flavors = ('Chocolate', 'Vanilla',
#                                       ^
# SyntaxError: incomplete input

# %%
flavors = ('Chocolate', 'Vanilla', 
'Pistachio', 'Mango', 'Strawberry')

# %%
votes = (12, 11, 4, 8, 7)

# %%
colors = ('#8B4513', '#FFF8DC', '#93C572', 
'#E67F0D', '#D53032')

# %%
explode = (0, 0, 0, 0.1, 0)

# %%
plt.title('Favorite Ice Cream Flavors')
# Out:
# Text(0.5, 1.0, 'Favorite Ice Cream Flavors')

# %%
plt.pie(
votes,
labels=flavors,
autopct='%1.1f%%',
colors=colors,
explode=explode,
shadow=True
)
# Out:
# ([<matplotlib.patches.Wedge at 0x2820f1ef550>,
#   <matplotlib.patches.Wedge at 0x2820f21aa10>,
#   <matplotlib.patches.Wedge at 0x2820f2254d0>,
#   <matplotlib.patches.Wedge at 0x2820f227c90>,
#   <matplotlib.patches.Wedge at 0x2820f236750>],
#  [Text(0.6858387475358717, 0.8600146582346299, 'Chocolate'),
#   Text(-0.952628012822497, 0.5499998810780423, 'Vanilla'),
#   Text(-0.9088625433128891, -0.6196522229144562, 'Pistachio'),
#   Text(-0.08967588289266856, -1.196644573809375, 'Mango'),
#   Text(0.9526280643171977, -0.5499997918865689, 'Strawberry')],
#  [Text(0.37409386229229363, 0.4690989044916162, '28.6%'),
#   Text(-0.5196152797213619, 0.2999999351334776, '26.2%'),
#   Text(-0.495743205443394, -0.3379921215897033, '9.5%'),
#   Text(-0.05231093168738999, -0.6980426680554686, '19.0%'),
#   Text(0.5196153078093805, -0.299999886483583, '16.7%')])

# %%
plt.show()
